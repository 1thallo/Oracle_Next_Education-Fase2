# %% [markdown]
# ## Aula 03 - Operações entre Arrays

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.plot(datas, Moscow)

# %% [markdown]
# ### Equação da reta de crescimento
# y = ax + b
#
# - a = Coeficiente angular -> Responsável pelo ângulo da reta
# - b = Coeficiente linear -> Aonde a reta corta o eixo Y

# %%
x = datas
y = 2*x + 80 #valor chute do coeficiente angular

plt.plot(x, Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow - y,2)))
# Out:
# np.float64(749.2329171225728)

# %%
y = 0.52*x + 80

plt.plot(x, Moscow)
plt.plot(x, y)

# %%
np.sqrt(np.sum(np.power(Moscow - y,2))) #variancia
# Out:
# np.float64(110.48504740461489)

# %%
np.linalg.norm(Moscow - y)
# Out:
# np.float64(110.48504740461489)

# %% [markdown]
# Multiplicação

# %% [markdown]
# - a = coeficiente angular
# - n -> número de elementos
# - Y = Moscow
# - X = datas

# %%
Y = Moscow
X = datas
n = np.size(Moscow)

# %%
(X ** 2).shape
# Out:
# (87,)

# %%
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y)) / (n*np.sum(X**2) - np.sum(X)**2) # coeficiente angular
print(a)
# Out:
# 0.43520212145512926

# %% [markdown]
# ## Coeficiente Linear

# %%
b = np.mean(Y) - a * np.mean(X)

# %%
y = a * X + b

# %%
np.linalg.norm(Moscow - y)
# Out:
# np.float64(101.7969539992751)

# %% [markdown]
# ## Motivo da regressão - estimando valores futuros

# %%
plt.plot(datas, Moscow)
plt.plot(x,y)
plt.plot(41.5, 41.5*a+b, '*r')
plt.plot(100, 100*a+b, '*r')
